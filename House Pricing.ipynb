# %%
# Import the necessary dependencies

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
housing_data = pd.read_csv("updated_house_data.csv")

housing_data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolQC Fence MiscFeature MiscVal MoSold YrSold  \
# 0         Lvl    AllPub  ...    NaN   NaN         NaN       0      2   2008
# 1         Lvl    AllPub  ...    NaN   NaN         NaN       0      5   2007
# 2         Lvl    AllPub  ...    NaN   NaN         NaN       0      9   2008
# 3         Lvl    AllPub  ...    NaN   NaN         NaN       0      2   2006
# 4         Lvl    AllPub  ...    NaN   NaN         NaN       0     12   2008
#
#   SaleType  SaleCondition  SalePrice  SalePrice Category
# ...

# %% [markdown]
# ### Exploratory Data Analysis

# %% [markdown]
# ### Understand the structure

# %%
#housing_data.info()

# %%
housing_data.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
housing_data.isnull().sum()
# Out:
# Id                      0
# BuildingClass           0
# ZoningClassification    0
# LotFrontage             0
# LotArea                 0
#                        ..
# YearSold                0
# SaleType                0
# SaleCondition           0
# SalePrice               0
# SalePrice Category      0
# Length: 82, dtype: int64

# %%
housing_data.shape
# Out:
# (1460, 82)

# %%
housing_data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1455    False
# 1456    False
# 1457    False
# 1458    False
# 1459    False
# Length: 1460, dtype: bool

# %%
housing_data['LotFrontage'].count()
# Out:
# np.int64(1201)

# %% [markdown]
# ### Understand the missing value

# %%
# investigating the missing values on the column LotFrontage

new_housing_data = housing_data.dropna(subset=['LotFrontage'], inplace=True) # dropping the missing values because their small

# %%
housing_data['LotFrontage'].unique()
# Out:
# array([ 65.,  80.,  68.,  60.,  84.,  85.,  75.,  51.,  50.,  70.,  91.,
#         72.,  66., 101.,  57.,  44., 110.,  98.,  47., 108., 112.,  74.,
#        115.,  61.,  48.,  33.,  52., 100.,  24.,  89.,  63.,  76.,  81.,
#         95.,  69.,  21.,  32.,  78., 121., 122.,  40., 105.,  73.,  77.,
#         64.,  94.,  34.,  90.,  55.,  88.,  82.,  71., 120., 107.,  92.,
#        134.,  62.,  86., 141.,  97.,  54.,  41.,  79., 174.,  99.,  67.,
#         83.,  43., 103.,  93.,  30., 129., 140.,  35.,  37., 118.,  87.,
#        116., 150., 111.,  49.,  96.,  59.,  36.,  56., 102.,  58.,  38.,
#        109., 130.,  53., 137.,  45., 106., 104.,  42.,  39., 144., 114.,
#        128., 149., 313., 168., 182., 138., 160., 152., 124., 153.,  46.])

# %%
housing_data_renamed_dict = {'MSSubClass': 'BuildingClass',
                        'MSZoning' : 'ZoningClassification',
                        'BldgType': 'BuildingType',
                       'YearRemodAdd': 'YearRemolded',
                       'MasVnrType': 'MasonryVeneerType',
                       'MasVnrArea' : 'MasonryVeneerArea', 
                        'BsmtQual' : 'BasementQuality',
                       'BsmtCond' : 'BasementCondition',
                        'BsmtFinType1' : 'BasementFinishType1',
                        'BsmtFinSF1': 'BasementFinishedArea1',
                       'BsmtFinType2' : 'BasementFinishType2',
                        'BsmtFinSF2': 'BasementFinishedArea2',
                        'BsmtUnfSF': 'BasementUnfinishedArea',
                        'TotalBsmtSF' : 'TotalBasementArea',
                        'HeatingQC' : 'HeatingQualityCondition', 
                        '1stFlrSF' : 'FirstFloorArea',
                        '2ndFlrSF' : 'SecondFloorArea',
                       'LowQualFinSF': 'LowQualityFinishedArea', 
                        'GrLivArea': 'LivingAreaAboveGround',
                       'BedroomAbvGr': 'BedroomAboveGround', 
                       'TotRmsAbvGrd' : 'TotalRoomsAboveGround', 
                       'GarageYrBlt' : 'GarageYearBuilt', 
                       'WoodDeckSF' : 'WoodDeckArea',
                        'OpenPorchSF' : 'OpenPorchArea',
                       '3SsnPorch': 'ThreeSeasonPorch', 
                       'PoolQC': 'PoolQuality', 
                       'MiscFeature' : 'MiscellaneousFeature',
                        'MiscVal' : 'MiscellaneousValue', 
                        'MoSold' : 'MonthSold', 
                        'YrSold' : 'YearSold'}                                  # renaming the column names to make it readable

# %%
housing_data.rename(columns=housing_data_renamed_dict, inplace=True)

# %%
housing_data.columns
# Out:
# Index(['Id', 'BuildingClass', 'ZoningClassification', 'LotFrontage', 'LotArea',
#        'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BuildingType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemolded',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd',
#        'MasonryVeneerType', 'MasonryVeneerArea', 'ExterQual', 'ExterCond',
#        'Foundation', 'BasementQuality', 'BasementCondition', 'BsmtExposure',
#        'BasementFinishType1', 'BasementFinishedArea1', 'BasementFinishType2',
#        'BasementFinishedArea2', 'BasementUnfinishedArea', 'TotalBasementArea',
#        'Heating', 'HeatingQualityCondition', 'CentralAir', 'Electrical',
#        'FirstFloorArea', 'SecondFloorArea', 'LowQualityFinishedArea',
#        'LivingAreaAboveGround', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
# ...

# %% [markdown]
# #### Understand the structure, missing values, and feature types.

# %%
# Select columns with numeric data types (int and float)

numerical_features = housing_data.select_dtypes(include=['number'])

numerical_features
# Out:
#         Id  BuildingClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0        1             60         65.0     8450            7            5
# 1        2             20         80.0     9600            6            8
# 2        3             60         68.0    11250            7            5
# 3        4             70         60.0     9550            7            5
# 4        5             60         84.0    14260            8            5
# ...    ...            ...          ...      ...          ...          ...
# 1455  1456             60         62.0     7917            6            5
# 1456  1457             20         85.0    13175            6            6
# 1457  1458             70         66.0     9042            7            9
# 1458  1459             20         68.0     9717            5            6
# 1459  1460             20         75.0     9937            5            6
#
#       YearBuilt  YearRemolded  MasonryVeneerArea  BasementFinishedArea1  ...  \
# ...

# %%
#Select columns with object data type (strings)

categorical_features = housing_data.select_dtypes(include=['object'])

categorical_features
# Out:
#      ZoningClassification Street Alley LotShape LandContour Utilities  \
# 0                      RL   Pave   NaN      Reg         Lvl    AllPub
# 1                      RL   Pave   NaN      Reg         Lvl    AllPub
# 2                      RL   Pave   NaN      IR1         Lvl    AllPub
# 3                      RL   Pave   NaN      IR1         Lvl    AllPub
# 4                      RL   Pave   NaN      IR1         Lvl    AllPub
# ...                   ...    ...   ...      ...         ...       ...
# 1455                   RL   Pave   NaN      Reg         Lvl    AllPub
# 1456                   RL   Pave   NaN      Reg         Lvl    AllPub
# 1457                   RL   Pave   NaN      Reg         Lvl    AllPub
# 1458                   RL   Pave   NaN      Reg         Lvl    AllPub
# 1459                   RL   Pave   NaN      Reg         Lvl    AllPub
#
#      LotConfig LandSlope Neighborhood Condition1  ... GarageFinish GarageQual  \
# ...

# %% [markdown]
# #### Visualize where necessary (histograms, boxplots, scatterplots, etc.)

# %%
# Histogram for SalePrice

plt.figure(figsize=(8, 6))
sns.histplot(housing_data["SalePrice"], kde=True, bins=40)
plt.title("Distribution of SalePrice")
plt.xlabel("SalePrice")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ##### Before modeling, I want to know if the target variable (SalePrice) is normally distributed.
# ##### A normal distribution would suit linear regression better, but here it looks right-skewed.
# ##### The distribution is right-skewed, causing the mean to exceed the median, pulling the average upwards
#
# ##### Note: Skewness typically tells you where the outliers occur. The outlier is on the right(high values)

# %%
# 2. Boxplot of SalePrice

plt.figure(figsize=(8, 6))
sns.boxplot(x=housing_data["SalePrice"])
plt.title("Boxplot of SalePrice")
plt.xlabel("SalePrice")
plt.show()

# %% [markdown]
# ##### Outliers in SalePrice could influence regression heavily.
# ##### This plot helps me identify unusually expensive houses that may distort the model.

# %%
# Scatterplot of OverallQual vs SalePrice

plt.figure(figsize=(8, 5))
sns.scatterplot(x=housing_data["OverallQual"], y=housing_data["SalePrice"], alpha=0.8)
plt.title("OverallQual vs SalePrice")
plt.xlabel("OverallQual")
plt.ylabel("SalePrice")
plt.show()

# %% [markdown]
# ##### Regression assumes some form of linear relationship between feature and target.
# #####  Scatterplots help me visually check if SalePrice rises with OverallQual hence linear.

# %%
Q1 = housing_data['SalePrice'].quantile(0.25)
Q3 = housing_data['SalePrice'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5*IQR
upper_bound = Q3 + 1.5*IQR

outliers = housing_data[(housing_data['SalePrice'] < lower_bound) | (housing_data['SalePrice'] > upper_bound)]

#outliers

# %%
selected_housing_data = housing_data[['OverallQual', 'YearBuilt', 'LotArea', 'SalePrice']]

selected_housing_data
# Out:
#       OverallQual  YearBuilt  LotArea  SalePrice
# 0               7       2003     8450     208500
# 1               6       1976     9600     181500
# 2               7       2001    11250     223500
# 3               7       1915     9550     140000
# 4               8       2000    14260     250000
# ...           ...        ...      ...        ...
# 1455            6       1999     7917     175000
# 1456            6       1978    13175     210000
# 1457            7       1941     9042     266500
# 1458            5       1950     9717     142125
# 1459            5       1965     9937     147500
#
# [1201 rows x 4 columns]

# %%
correlations = selected_housing_data.corr(numeric_only=True)['SalePrice']  # To correlate the numeric features (OverallQual, YearBuilt, and LotArea) with SalePrice

print(correlations[['OverallQual', 'YearBuilt', 'LotArea']])
# Out:
# OverallQual    0.802287
# YearBuilt      0.538913
# LotArea        0.311416
# Name: SalePrice, dtype: float64

# %% [markdown]
# ##### I selected OverallQual as the predictor feature because exploratory analysis showed it has one of the strongest correlations with SalePrice. Unlike other features such as LotArea, which can have large variability, OverallQual provides a consistent and interpretable measure of house quality that strongly influences price.

# %%
# Feature Matrix

#X_housing_data= housing_data.drop('SalePrice', axis=1)
X_housing_data = housing_data[['OverallQual']] 

X_housing_data.shape
# Out:
# (1201, 1)

# %%
# Target Vector

y_housing_data = housing_data['SalePrice']

y_housing_data.shape
# Out:
# (1201,)

# %%
from sklearn.model_selection import train_test_split

# Split data: 80% training, 20% testing
X_train, X_test, y_train, y_test = train_test_split(X_housing_data, y_housing_data, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# initializing the model

model = LinearRegression()
model.fit(X_housing_data, y_housing_data)

y_pred = model.predict(X_housing_data)

# %%
# fit the model on feature X and target y

model.fit(X_housing_data, y_housing_data)
# Out:
# LinearRegression()

# %%
# predict the model

y_pred = model.predict(X_housing_data)

y_pred
# Out:
# array([222140.97417758, 175000.59183671, 222140.97417758, ...,
#        222140.97417758, 127860.20949585, 127860.20949585])

# %%
from sklearn.metrics import mean_squared_error, r2_score

mse = mean_squared_error(y_housing_data, y_pred)
r2 = r2_score(y_housing_data, y_pred)

print("Mean Squared Error:", mse)
print("R-squared:", r2)
# Out:
# Mean Squared Error: 2475822278.0631456
# R-squared: 0.6436651645231863

# %% [markdown]
# #### The model achieved an R-Squared of 0.64, indicating that 64% of the variation in house prices can be explained by the quality rating (OverallQual).
# #### The RMSE was approximately 50,000(USD)  suggesting that predictions are, on average, off by about $50,000 compared to actual sale prices.

# %%
plt.scatter(X_housing_data, y_housing_data, color='blue', label="Actual")
plt.plot(X_housing_data, y_pred, color='red', label="Predicted Line")
plt.xlabel("Overall Quality")
plt.ylabel("Sale Price")
plt.title("Linear Regression: OverallQual vs SalePrice")
plt.legend()
plt.show()

# %%
from sklearn.ensemble import RandomForestRegressor

# Train Random Forest
model = RandomForestRegressor(n_estimators=100, random_state=42)

randomforest_model.fit(X_train, y_train)
y_pred_randomforest = randomforest_model.predict(X_test)

# %%
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
predictions = model.predict(X_test)

#predictions

# %%
from sklearn.metrics import mean_squared_error, r2_score

print(f"Mean Squared Error: {mean_squared_error(y_test, predictions)}")
print(f"R-squared: {r2_score(y_test, predictions)}")
# Out:
# Mean Squared Error: 2415403050.4572053
# R-squared: 0.7305148682865045

# %% [markdown]
# #### Model Comparison: Linear Regression vs. Random Forest Regressor

# %% [markdown]
# ### We evaluated two models: Linear Regression and Forest Regression using OverallQual as the predictor for SalePrice.
#
# #### - Linear Regression Results;
# ##### Mean Squared Error (MSE): 2,475,822,278.06
# ##### R-squared: 0.64
#
# #### Random Forest Regressor Results;
# ##### Mean-Squared Error(MSE): 2,415,403,050.46
# ##### R-Squared: 0.73

# %% [markdown]
# #### Interpretation:
#
# ##### Linear Regression captured the general linear trend between house quality (OverallQual) and price, but its R² value of 0.64 shows it could explain about 64% of the variance in house prices.
#
# ##### Random Forest Regressor improved performance, reducing prediction error slightly increased R-Squared to 0.73, meaning it explains about 73% of the variance.
#
# #### Conclusion:
# ##### Random Forest Regressor provided more accurate predictions than Linear Regression, showing that non-linear ensemble methods can better capture the relationship between housing quality and price.

# %% [markdown]
# [Report](https://docs.google.com/document/d/12lqNlq9ucstrRHEXZpXWhREHYBgft_L1iXL4kqzA0i0/edit?usp=sharing)
